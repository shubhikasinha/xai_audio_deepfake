# %%
# 1. Clean previous directories if any, clone fresh repo, and enter the folder
# %cd /kaggle/working
# !rm -rf deepfake-xai-robustness
# !git clone https://github.com/shubhikasinha/xai_audio_deepfake.git deepfake-xai-robustness
# %cd /kaggle/working/deepfake-xai-robustness
# Out:
# /kaggle/working
# Cloning into 'deepfake-xai-robustness'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 82 (delta 18), reused 82 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 62.80 KiB | 7.85 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /kaggle/working/deepfake-xai-robustness

# %%
# 2. Map Kaggle input datasets to the expected project data directory structure
# !mkdir -p data

# Link ASVspoof 2019 LA
# !ln -sf /kaggle/input/asv-spoof-2019/LA/LA data/ASVspoof2019_LA

# Link ASVspoof 2021 DF
# !ln -sf /kaggle/input/asvspoof-2021-dataset/ASVspoof2021_DF_eval/ASVspoof2021_DF_eval data/ASVspoof2021_DF

# Link MUSAN Noise Dataset
# !ln -sf /kaggle/input/starter-musan-noise-b2c57001-3/musan data/MUSAN

print("✓ Mapped directories in data/:")
# !ls -la data/
# Out:
# ✓ Mapped directories in data/:
# total 12
# drwxr-xr-x  2 root root 4096 Jul 21 14:40 .
# drwxr-xr-x 11 root root 4096 Jul 21 14:40 ..
# lrwxrwxrwx  1 root root   34 Jul 21 14:40 ASVspoof2019_LA -> /kaggle/input/asv-spoof-2019/LA/LA
# lrwxrwxrwx  1 root root   77 Jul 21 14:40 ASVspoof2021_DF -> /kaggle/input/asvspoof-2021-dataset/ASVspoof2021_DF_eval/ASVspoof2021_DF_eval
# lrwxrwxrwx  1 root root   50 Jul 21 14:40 MUSAN -> /kaggle/input/starter-musan-noise-b2c57001-3/musan

# %%
# 3. Upgrade pip and install all package requirements
# !pip install -q -r requirements.txt

# Ensure compatibility versions for PyTorch + Numba in Kaggle environment
# !pip install -q "numpy>=2.0.0,<2.5.0" --force-reinstall

# Install the deepfake package in editable/development mode
# !pip install -q -e .

print("✓ Setup and installation completed successfully!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.9/648.9 kB 17.7 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 66.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 59.1 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.2/455.2 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.0/204.0 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 27.8 MB/s eta 0:00:00
# ...

# %%
# 4. Run the end-to-end quick-test pipeline using inline path execution
# %cd /kaggle/working/deepfake-xai-robustness
# !python -c "import sys; sys.path.insert(0, '/kaggle/working/deepfake-xai-robustness'); from scripts.run_full_pipeline import main; main()" --quick-test
# Out:
# /kaggle/working/deepfake-xai-robustness
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/kaggle/working/deepfake-xai-robustness/scripts/run_full_pipeline.py", line 34, in <module>
#     from src.xai.integrated_gradients import IntegratedGradientsExplainer
#   File "/kaggle/working/deepfake-xai-robustness/src/xai/integrated_gradients.py", line 21, in <module>
#     from src.data.utils import compute_spectrogram
# ModuleNotFoundError: No module named 'src.data'
